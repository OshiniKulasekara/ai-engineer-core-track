# %%
import os
from dotenv import load_dotenv

# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('GEMINI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please check your .env file has GEMINI_API_KEY set!")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them!")
else:
    print("Gemini API key found and looks good so far!")
# Out:
# Gemini API key found and looks good so far!

# %%
import requests

headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}

payload = {
    "model": "gemini-2.5-flash",
    "messages": [
        {"role": "user", "content": "Tell me a fun fact"}]
}

payload
# Out:
# {'model': 'gemini-2.5-flash',
#  'messages': [{'role': 'user', 'content': 'Tell me a fun fact'}]}

# %%
response = requests.post(
    "https://generativelanguage.googleapis.com/v1beta/openai/chat/completions",
    headers=headers,
    json=payload
)

response.json()
# Out:
# {'choices': [{'finish_reason': 'stop',
#    'index': 0,
#    'message': {'content': 'Here\'s one!\n\nDid you know that **bananas are technically considered berries, while strawberries are not**?\n\nIt\'s all about the botanical definition! Berries are fruits that come from a single flower with one ovary, and have multiple seeds. Bananas fit that description. Strawberries, on the other hand, develop from a single flower with multiple ovaries, making them an "aggregate fruit."',
#     'role': 'assistant'}}],
#  'created': 1788516453,
#  'id': 'X5iaaoSvJfGAg8UP_Y3HsQ0',
#  'model': 'gemini-2.5-flash',
#  'object': 'chat.completion',
#  'usage': {'completion_tokens': 83, 'prompt_tokens': 6, 'total_tokens': 719}}

# %%
response.json()["choices"][0]["message"]["content"]
# Out:
# 'Here\'s one!\n\nDid you know that **bananas are technically considered berries, while strawberries are not**?\n\nIt\'s all about the botanical definition! Berries are fruits that come from a single flower with one ovary, and have multiple seeds. Bananas fit that description. Strawberries, on the other hand, develop from a single flower with multiple ovaries, making them an "aggregate fruit."'

# %%
# Create Gemini client via the OpenAI-compatible API

from openai import OpenAI

openai = OpenAI(
    api_key=api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
)

response = openai.chat.completions.create(
    model="gemini-2.5-flash",
    messages=[{"role": "user", "content": "Tell me a fun fact"}],
)

response.choices[0].message.content
# Out:
# 'Did you know that **honey never spoils**?\n\nArchaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old and still perfectly edible! Its unique chemical composition (low water content, high sugar concentration, and acidity) makes it an inhospitable environment for bacteria and other microorganisms.'

# %%
requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
# Get a fun fact
# Use the tag that is actually installed locally (ollama list / /api/tags)

response = ollama.chat.completions.create(
    model="llama3.2:1b",
    messages=[{"role": "user", "content": "Tell me a fun fact"}],
)

response.choices[0].message.content
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Get a fun fact
#       2
# ----> 3 response = ollama.chat.completions.create(model="llama3.2", messages=[{"role": "user", "content": "Tell me a fun fact"}])
#       4
#       5 response.choices[0].message.content
#
# File ~\OneDrive - Arcadea Group\Desktop\Python\AI-Courses\ai-engineer-core-track\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# ...

# %%
# Now let's try deepseek-r1:1.5b - this is DeepSeek "distilled" into Qwen from Alibaba Cloud

# !ollama pull deepseek-r1:1.5b

# %%
response = ollama.chat.completions.create(model="deepseek-r1:1.5b", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content

# %%
# imports

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('GEMINI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please check your .env file has GEMINI_API_KEY set!")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them!")
else:
    print("Gemini API key found and looks good so far!")
# Out:
# Gemini API key found and looks good so far!

# %%
message = "Hello, Gemini! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, Gemini! This is my first ever message to you! Hi!'}]

# %%
openai = OpenAI(
    api_key=api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
)

MODEL = "gemini-3.5-flash-lite"

response = openai.chat.completions.create(model=MODEL, messages=messages)
response.choices[0].message.content
# Out:
# '2 + 2 = 4'

# %%
# Let's try out this utility

ed = fetch_website_contents("https://edwarddonner.com")
print(ed)
# Out:
# Home - Edward Donner
#
# Skip to content
# Avatar
# Curriculum
# Proficiency
# C4
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of AI startup
# Nebula.io
# . I was previously founder and CEO of AI startup untapt,
# acquired in 2021
# , and a Managing Director at JPMorgan.
# I will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 900,000 enrollments across 194 countries. The
# full curriculum is here
# . If you’re visiting from one of my courses – I’m super grateful!
# For more on me and my courses, please
# chat with me and my Digital Avatar here
# .
# February 17, 2026
# AI Coder: Vibe Coder to Agentic Engineer – RESOURCES
# January 4, 2026
# AI Builder with n8n – Create Agents and Voice Agents – RESOURCES
# September 15, 2025
# AI Engineering MLOps Track – Deploy AI to Production – RESOURCES
# May 28, 2025
# Which order to take the AI courses?
# Navigation
# Avatar
# Curriculum
# Proficiency
# C4
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Get in touch
# ed [at] edwarddonner [dot] com
# www.edwarddonner.com
# Follow me
# LinkedIn
# Twitter
# Facebook

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# Define our user prompt

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

response = openai.chat.completions.create(model=MODEL, messages=messages)
response.choices[0].message.content
# Out:
# '2 + 2 = 4'

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
# Try this out, and then try for a few more websites

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a snarky assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n'},
#  {'role': 'user',
#   'content': '\nHere are the contents of a website.\nProvide a short summary of this website.\nIf it includes news or announcements, then summarize these too.\n\nHome - Edward Donner\n\nSkip to content\nAvatar\nCurriculum\nProficiency\nC4\nOutsmart\nAn arena that pits LLMs against each other in a battle of diplomacy and deviousness\nAbout\nPosts\nWell, hi there.\nI’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (\nvery\namateur) and losing myself in\nHacker News\n, nodding my head sagely to things I only half understand.\nI’m the co-founder and CTO of AI startup\nNebula.io\n. I was previously founder and CEO of AI startup untapt,\nacquired in 2021\n, and a Managing Director at JPMorgan.\nI will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 900,000 enrollments across 194 countries. The\nfull curriculum is here\n. If you’re visiting from one of my courses – I’m super grateful!\nFor more on me and my courses, please\nchat with me and my Digital Avatar here\n.\nFebruary 17, 2026\nAI Coder: Vibe Coder to Agentic Engineer – RESOURCES\nJanuary 4, 2026\nAI Builder with n8n – Create Agents and Voice Agents – RESOURCES\nSeptember 15, 2025\nAI Engineering MLOps Track – Deploy AI to Production – RESOURCES\nMay 28, 2025\nWhich order to take the AI courses?\nNavigation\nAvatar\nCurriculum\nProficiency\nC4\nOutsmart\nAn arena that pits LLMs against each other in a battle of diplomacy and deviousness\nAbout\nPosts\nGet in touch\ned [at] edwarddonner [dot] com\nwww.edwarddonner.com\nFollow me\nLinkedIn\nTwitter\nFacebook'}]

# %%
# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(model=MODEL, messages= messages_for(website))
    return response.choices[0].message.content

# %%
summarize("https://edwarddonner.com")
# Out:
# "### What is this place?\nBehold the digital ego-shrine of Edward Donner: startup founder, AI enthusiast, and the man responsible for inflicting best-selling Udemy courses on nearly a million unsuspecting souls. When he's not busy droning on about Large Language Models until his friends flee in terror, he's building AI startups and pretending to understand Hacker News. \n\n### Recent Dispatches from the AI Hype Train\n* **February 17, 2026:** AI Coder: Vibe Coder to Agentic Engineer (Because just guessing code wasn't chaotic enough).\n* **January 4, 2026:** AI Builder with n8n (More agents, more voice, more reasons to question humanity's future).\n* **September 15, 2025:** AI Engineering MLOps Track (For when you actually have to deploy this stuff instead of just talking about it).\n* **May 28, 2025:** Which order to take the AI courses? (A crucial roadmap for the terminally overwhelmed)."

# %%
# A function to display this nicely in the output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")
# Out:
# ### Summary
#
# Behold the digital ego-shrine of Edward Donner, a startup co-founder, former big-bank bigwig, and professional LLM-splainer. Since his real-life friends wisely threatened to stop hanging out with him if he kept lecturing them about artificial intelligence, he pivoted to selling Udemy courses to nearly a million unsuspecting souls. Now, he spends his time making amateur bleep-bloop electronic music and pretending to understand Hacker News.
#
# ### Recent Dispatches From the AI Overlord
#
# * **February 17, 2026:** *AI Coder: Vibe Coder to Agentic Engineer – RESOURCES* (For when just "vibe-coding" isn't enough and you need a fancy title to justify your prompt-copying habit).
# * **January 4, 2026:** *AI Builder with n8n – Create Agents and Voice Agents – RESOURCES* (Because the world desperately needed more AI agents calling people on the phone).
# * **September 15, 2025:** *AI Engineering MLOps Track – Deploy AI to Production – RESOURCES* (How to break things in production, but with machine learning).
# * **May 28, 2025:** *Which order to take the AI courses?* (A handy guide on how to hand over your hard-earned money in the statistically most efficient sequence).

# %%
display_summary("https://cnn.com")
# Out:
# ### Website Summary
# Congratulations, you've stumbled upon CNN.com! It's a digital wasteland where actual journalism fights a losing battle against an endless abyss of global panic, endless dropdown menus, and surveys asking how much you hate their video ads.
#
# ### News & Announcements
# * **Breaking News:** An ad froze, a video refused to load, and CNN desperately wants you to fill out a customer satisfaction survey about it.
# * **Global Updates:** The world is still on fire (Ukraine, Israel, climate change, etc.), but please make sure to check out the "Fear & Greed" index before you panic-buy more toilet paper.

# %%
display_summary("https://anthropic.com")
# Out:
# ### What is this?
# Welcome to the Anthropic homepage, where a terrifying amount of navigation menus try to distract you from the fact that they are just trying to sell you another chatbot named after a poetry genre.
#
# ### News & Announcements
# * **New Models Drop:** Behold *Fable 5.1*, *Mythos 5.1*, and *Opus 5*—because calling your robots normal names like "Bot v3" is apparently illegal in Silicon Valley. Supposedly, they are great at coding and knowledge work, which mostly means they'll be doing your job by July.

# %%
# Step 1: Create your prompts

system_prompt = "You are a helpful assistant that answers clearly and concisely."
user_prompt = """
Explain what an LLM is in two short sentences.
"""

# Step 2: Make the messages list

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt},
]

# Step 3: Call Gemini (OpenAI-compatible client)
response = openai.chat.completions.create(model=MODEL, messages=messages)

# Step 4: print the result
print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[29], line 14
#      10
#      11 messages = [] # fill this in
#      12
#      13 # Step 3: Call OpenAI
# ---> 14 response = openai.chat.completions.create(model=MODEL, messages=messages)
#      15
#      16 # Step 4: print the result
#      17 print(response.choices[0].message.content)
#
# File ~\OneDrive - Arcadea Group\Desktop\Python\AI-Courses\ai-engineer-core-track\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~\OneDrive - Arcadea Group\Desktop\Python\AI-Courses\ai-engineer-core-track\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1296, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1247 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1248 def create(
#    1249     self,
#    (...)   1293     timeout: float | httpx2.Timeout | None | NotGiven = not_given,
#    1294 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1295     validate_response_format(response_format)
# -> 1296     return self._post(
#    1297         "/chat/completions",
#    1298         body=maybe_transform(
#    1299             {
#    1300                 "messages": messages,
#    1301                 "model": model,
#    1302                 "audio": audio,
#    1303                 "frequency_penalty": frequency_penalty,
#    1304                 "function_call": function_call,
#    1305                 "functions": functions,
#    1306                 "logit_bias": logit_bias,
#    1307                 "logprobs": logprobs,
#    1308                 "max_completion_tokens": max_completion_tokens,
#    1309                 "max_tokens": max_tokens,
#    1310                 "metadata": metadata,
#    1311                 "modalities": modalities,
#    1312                 "moderation": moderation,
#    1313                 "n": n,
#    1314                 "parallel_tool_calls": parallel_tool_calls,
#    1315                 "prediction": prediction,
#    1316                 "presence_penalty": presence_penalty,
#    1317                 "prompt_cache_key": prompt_cache_key,
#    1318                 "prompt_cache_options": prompt_cache_options,
#    1319                 "prompt_cache_retention": prompt_cache_retention,
#    1320                 "reasoning_effort": reasoning_effort,
#    1321                 "response_format": response_format,
#    1322                 "safety_identifier": safety_identifier,
#    1323                 "seed": seed,
#    1324                 "service_tier": service_tier,
#    1325                 "stop": stop,
#    1326                 "store": store,
#    1327                 "stream": stream,
#    1328                 "stream_options": stream_options,
#    1329                 "temperature": temperature,
#    1330                 "tool_choice": tool_choice,
#    1331                 "tools": tools,
#    1332                 "top_logprobs": top_logprobs,
#    1333                 "top_p": top_p,
#    1334                 "user": user,
#    1335                 "verbosity": verbosity,
#    1336                 "web_search_options": web_search_options,
#    1337             },
#    1338             completion_create_params.CompletionCreateParamsStreaming
#    1339             if stream
#    1340             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1341         ),
#    1342         options=make_request_options(
#    1343             extra_headers=extra_headers,
#    1344             extra_query=extra_query,
#    1345             extra_body=extra_body,
#    1346             timeout=timeout,
#    1347             security={"bearer_auth": True},
#    1348         ),
#    1349         cast_to=ChatCompletion,
#    1350         stream=stream or False,
#    1351         stream_cls=Stream[ChatCompletionChunk],
#    1352     )
#
# File ~\OneDrive - Arcadea Group\Desktop\Python\AI-Courses\ai-engineer-core-track\.venv\Lib\site-packages\openai\_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1359     warnings.warn(
#    1360         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1361         "Please pass raw bytes via the `content` parameter instead.",
#    1362         DeprecationWarning,
#    1363         stacklevel=2,
#    1364     )
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\OneDrive - Arcadea Group\Desktop\Python\AI-Courses\ai-engineer-core-track\.venv\Lib\site-packages\openai\_base_client.py:1141, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1138             err.response.read()
#    1140         log.debug("Re-raising status error")
# -> 1141         raise self._make_status_error_from_response(err.response) from None
#    1143     break
#    1145 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - [{'error': {'code': 400, 'message': '* GenerateContentRequest.contents: contents is not specified\n', 'status': 'INVALID_ARGUMENT'}}]
